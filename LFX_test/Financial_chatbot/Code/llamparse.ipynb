# %%
# !pip install llama-index-core llama-parse llama-index-readers-file python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 75.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 46.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 18.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.2
#     Uninstalling beautifulsoup4-4.12.2:
# ...

# %%
import nest_asyncio
nest_asyncio.apply()

# Bring in dependencies
from llama_parse import LlamaParse
from llama_index.core import SimpleDirectoryReader

# Set up the parser with the API key
parser = LlamaParse(
    api_key="enter keys here",
    result_type="markdown" 
)

# Use SimpleDirectoryReader to parse your file
file_extractor = {".pdf": parser}
documents = SimpleDirectoryReader(input_files=['/kaggle/input/lfx-test/FY24_Q2_Consolidated_Financial_Statements.pdf'], file_extractor=file_extractor).load_data()

print(documents)
# Out:
# Started parsing the file under job_id e67c04c1-7554-4872-98f9-61ce97cc7419
# ...
